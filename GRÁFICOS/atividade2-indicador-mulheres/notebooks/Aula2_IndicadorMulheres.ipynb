# %%
# No terminal, uma vez: python -m pip install xlrd pandas
import pandas as pd

# %%
path = "../dados/Tabela_1_1_1.xls"

# %%
indicador_1 = pd.read_excel(path, engine="xlrd")

# %%
indicador_1
# Out:
#    Tabela 1.1.1 - Número médio de horas semanais dedicadas aos cuidados de pessoas e/ou afazeres domésticos das pessoas de 14 anos ou mais de idade, na semana de referência, por sexo e cor ou raça, segundo Grandes Regiões e Unidades da Federação - Brasil - 2022  \
# 0                                                 NaN
# 1                                                 NaN
# 2             Grandes Regiões e Unidades da Federação
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                              Brasil
# 8                                               Norte
# 9                                            Rondônia
# 10                                               Acre
# 11                                           Amazonas
# 12                                            Roraima
# 13                                               Pará
# 14                                              Amapá
# 15                                          Tocantins
# 16                                           Nordeste
# 17                                           Maranhão
# 18                                              Piauí
# 19                                              Ceará
# 20                                Rio Grande do Norte
# 21                                            Paraíba
# 22                                         Pernambuco
# 23                                            Alagoas
# 24                                            Sergipe
# 25                                              Bahia
# 26                                            Sudeste
# 27                                       Minas Gerais
# 28                                     Espírito Santo
# 29                                     Rio de Janeiro
# 30                                          São Paulo
# 31                                                Sul
# 32                                             Paraná
# 33                                     Santa Catarina
# 34                                  Rio Grande do Sul
# 35                                       Centro-Oeste
# 36                                 Mato Grosso do Sul
# 37                                        Mato Grosso
# 38                                              Goiás
# 39                                   Distrito Federal
# 40                                                NaN
# 41  Fonte: IBGE. Pesquisa Nacional por Amostra de ...
# 42                                             Notas:
# 43  (1) Calculado apenas para as pessoas que decla...
# 44  (2) Exclusive as pessoas sem declaração das ho...
#
#                                            Unnamed: 1              Unnamed: 2  \
# 0                                                 NaN                     NaN
# 1                                                 NaN                     NaN
# 2   Número médio de horas semanais dedicadas aos c...                     NaN
# 3                                                 NaN                     NaN
# 4                                               Total  Por sexo e cor ou raça
# 5                                                 NaN                   Total
# 6                                                 NaN                  Branca
# 7                                           16.985781                16.54593
# 8                                           16.187037               15.925246
# 9                                           17.014162               16.727733
# 10                                          13.606903               13.806929
# 11                                           16.80729               15.987545
# 12                                          13.639257               13.651755
# 13                                          16.474268               16.181627
# 14                                          13.586656                14.38918
# 15                                          15.815781               15.701788
# 16                                          18.499396                 18.1517
# 17                                          16.669614               16.421773
# 18                                          17.960366               16.948094
# 19                                          19.499293                18.52712
# 20                                           18.30774               18.101853
# 21                                          18.920816                18.88792
# 22                                          19.306249               18.950219
# 23                                          20.217129               19.165111
# 24                                          18.826541               17.264294
# 25                                          17.849776               17.538007
# 26                                          17.104218               16.834863
# 27                                          17.502141               17.179387
# 28                                          17.111106                16.51061
# 29                                          16.716263               16.097467
# 30                                          17.071295               16.964437
# 31                                          15.527769               15.570983
# 32                                          15.390122               15.453295
# 33                                          16.039355               16.124417
# 34                                          15.356709               15.337269
# 35                                          15.000763               14.826985
# 36                                          15.309783               14.902105
# 37                                          14.239989               14.083513
# 38                                          15.186471               14.962622
# 39                                          15.096351               15.061306
# 40                                                NaN                     NaN
# 41                                                NaN                     NaN
# 42                                                NaN                     NaN
# 43                                                NaN                     NaN
# 44                                                NaN                     NaN
#
#         Unnamed: 3 Unnamed: 4      Unnamed: 5 Unnamed: 6      Unnamed: 7
# 0              NaN        NaN             NaN        NaN             NaN
# 1              NaN        NaN             NaN        NaN             NaN
# 2              NaN        NaN             NaN        NaN             NaN
# 3              NaN        NaN             NaN        NaN             NaN
# 4              NaN        NaN             NaN        NaN             NaN
# 5              NaN      Homem             NaN     Mulher             NaN
# 6   Preta ou parda     Branca  Preta ou parda     Branca  Preta ou parda
# 7        17.333142  11.705136        11.74633  20.404106       22.037998
# 8        16.256032  11.588653       11.514646   19.29578       20.534188
# 9        17.101523  12.111127        12.54408  20.412887        21.06141
# 10       13.541399   10.79612        9.686983  16.130352       16.710754
# 11       16.995493  12.233043       12.822584  18.764969       20.716986
# 12       13.633606  10.814803       10.476601  16.135877       16.560244
# 13       16.560239  11.524306       11.026707   19.83511       21.591144
# 14       13.415091  11.116821       10.749444  16.648579       15.908487
# 15       15.768728  10.733863       11.682616  19.663713       19.629399
# 16       18.610911  11.723907       11.848436  22.744666       23.716716
# 17       16.708894  11.665173       11.437359  19.881056       20.739589
# 18       18.231789  12.258324       11.204814  20.494063        23.69544
# 19       19.882469  12.186936       12.821323  23.019718       24.952274
# 20       18.445218  11.166909       11.086286   23.54708       24.422884
# 21       18.945306  12.480204       12.400831  23.642936        24.03565
# 22       19.418444  12.312833       12.868821   23.35788       24.243396
# 23       20.560451  12.121839        13.35716  24.093655       25.856637
# 24       19.317934  10.830511       11.270341  21.740902       25.637681
# 25       17.935566  10.551673       10.982808   22.57273       23.217119
# 26       17.397989  11.933522       12.180843  20.732969       21.990431
# 27       17.707564   11.31972        11.61912   22.18665       23.075751
# 28       17.478861  11.798571       12.017589  20.464462       22.196626
# 29        17.24306  12.000036       12.864896  19.203741       20.957728
# 30        17.25548  12.123044         12.2352  20.771186        21.76762
# 31       15.406088  11.546629       11.159487  19.012969       19.338734
# 32       15.307289  11.240085       10.815611  18.896661        19.36538
# 33       15.616235  12.339052       11.517342  19.414764       19.646573
# 34       15.448203  11.308447       11.519941   18.86823        19.10772
# 35       15.078025  10.546799       10.332059  18.220683        19.33104
# 36       15.567204  10.446213        11.12692    18.5932       19.542761
# 37       14.270209   9.479654        9.265734  17.782825       18.695923
# 38       15.296966  10.636424       10.531883  18.440842       19.587913
# 39       15.126295  11.377952       10.481279  17.738123       19.307332
# 40             NaN        NaN             NaN        NaN             NaN
# 41             NaN        NaN             NaN        NaN             NaN
# 42             NaN        NaN             NaN        NaN             NaN
# 43             NaN        NaN             NaN        NaN             NaN
# 44             NaN        NaN             NaN        NaN             NaN

# %% [markdown]
# O `.xls` do IBGE mistura **título**, cabeçalho em várias linhas e **notas no rodapé**.
# Cortamos isso e deixamos só: **nomes das colunas + números**.

# %% [markdown]
# Tabela 1.1.1 - Número médio de horas semanais dedicadas aos cuidados de pessoas e/ou afazeres domésticos das pessoas de 14 anos ou mais de idade, na semana de referência, por sexo e cor ou raça, segundo Grandes Regiões e Unidades da Federação - Brasil - 2022

# %%
# Lê sem usar a 1ª linha como nome de coluna (senão o título vira "coluna")
bruto = pd.read_excel(path, engine="xlrd", header=None)

# Linhas 0–7: título/cabeçalho  |  8–40: resultados  |  41+: fonte e notas
indicador_1 = bruto.iloc[8:41].copy()
indicador_1.columns = [
    "uf_regiao",
    "total",
    "total_branca",
    "total_preta_parda",
    "homem_branca",
    "homem_preta_parda",
    "mulher_branca",
    "mulher_preta_parda",
]
indicador_1 = indicador_1.reset_index(drop=True)

# horas são número, não texto
for col in indicador_1.columns[1:]:
    indicador_1[col] = pd.to_numeric(indicador_1[col], errors="coerce")

indicador_1
# Out:
#               uf_regiao      total  total_branca  total_preta_parda  \
# 0                Brasil  16.985781     16.545930          17.333142
# 1                 Norte  16.187037     15.925246          16.256032
# 2              Rondônia  17.014162     16.727733          17.101523
# 3                  Acre  13.606903     13.806929          13.541399
# 4              Amazonas  16.807290     15.987545          16.995493
# 5               Roraima  13.639257     13.651755          13.633606
# 6                  Pará  16.474268     16.181627          16.560239
# 7                 Amapá  13.586656     14.389180          13.415091
# 8             Tocantins  15.815781     15.701788          15.768728
# 9              Nordeste  18.499396     18.151700          18.610911
# 10             Maranhão  16.669614     16.421773          16.708894
# 11                Piauí  17.960366     16.948094          18.231789
# 12                Ceará  19.499293     18.527120          19.882469
# 13  Rio Grande do Norte  18.307740     18.101853          18.445218
# 14              Paraíba  18.920816     18.887920          18.945306
# 15           Pernambuco  19.306249     18.950219          19.418444
# 16              Alagoas  20.217129     19.165111          20.560451
# 17              Sergipe  18.826541     17.264294          19.317934
# 18                Bahia  17.849776     17.538007          17.935566
# 19              Sudeste  17.104218     16.834863          17.397989
# 20         Minas Gerais  17.502141     17.179387          17.707564
# 21       Espírito Santo  17.111106     16.510610          17.478861
# 22       Rio de Janeiro  16.716263     16.097467          17.243060
# 23            São Paulo  17.071295     16.964437          17.255480
# 24                  Sul  15.527769     15.570983          15.406088
# 25               Paraná  15.390122     15.453295          15.307289
# 26       Santa Catarina  16.039355     16.124417          15.616235
# 27    Rio Grande do Sul  15.356709     15.337269          15.448203
# 28         Centro-Oeste  15.000763     14.826985          15.078025
# 29   Mato Grosso do Sul  15.309783     14.902105          15.567204
# 30          Mato Grosso  14.239989     14.083513          14.270209
# 31                Goiás  15.186471     14.962622          15.296966
# 32     Distrito Federal  15.096351     15.061306          15.126295
#
#     homem_branca  homem_preta_parda  mulher_branca  mulher_preta_parda
# 0      11.705136          11.746330      20.404106           22.037998
# 1      11.588653          11.514646      19.295780           20.534188
# 2      12.111127          12.544080      20.412887           21.061410
# 3      10.796120           9.686983      16.130352           16.710754
# 4      12.233043          12.822584      18.764969           20.716986
# 5      10.814803          10.476601      16.135877           16.560244
# 6      11.524306          11.026707      19.835110           21.591144
# 7      11.116821          10.749444      16.648579           15.908487
# 8      10.733863          11.682616      19.663713           19.629399
# 9      11.723907          11.848436      22.744666           23.716716
# 10     11.665173          11.437359      19.881056           20.739589
# 11     12.258324          11.204814      20.494063           23.695440
# 12     12.186936          12.821323      23.019718           24.952274
# 13     11.166909          11.086286      23.547080           24.422884
# 14     12.480204          12.400831      23.642936           24.035650
# 15     12.312833          12.868821      23.357880           24.243396
# 16     12.121839          13.357160      24.093655           25.856637
# 17     10.830511          11.270341      21.740902           25.637681
# 18     10.551673          10.982808      22.572730           23.217119
# 19     11.933522          12.180843      20.732969           21.990431
# 20     11.319720          11.619120      22.186650           23.075751
# 21     11.798571          12.017589      20.464462           22.196626
# 22     12.000036          12.864896      19.203741           20.957728
# 23     12.123044          12.235200      20.771186           21.767620
# 24     11.546629          11.159487      19.012969           19.338734
# 25     11.240085          10.815611      18.896661           19.365380
# 26     12.339052          11.517342      19.414764           19.646573
# 27     11.308447          11.519941      18.868230           19.107720
# 28     10.546799          10.332059      18.220683           19.331040
# 29     10.446213          11.126920      18.593200           19.542761
# 30      9.479654           9.265734      17.782825           18.695923
# 31     10.636424          10.531883      18.440842           19.587913
# 32     11.377952          10.481279      17.738123           19.307332

# %%
# Média nacional = linha Brasil (dado do IBGE), não a média das linhas da tabela
media_nacional = indicador_1.loc[indicador_1["uf_regiao"] == "Brasil", "total"].item()
media_nacional
# Out:
# 16.985780816563242

# %%
media_nacional
# Out:
# 16.985780816563242

# %% [markdown]
# Qual(is) estado(s) está acima da média nacional de afazeres domésticos?

# %%
regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]

estados = indicador_1[~indicador_1["uf_regiao"].isin(["Brasil"] + regioes)]

acima_media = estados.loc[
    estados["total"] > media_nacional,
    ["uf_regiao", "total"],
].sort_values("total", ascending=False)

print(f"Média nacional (Brasil): {media_nacional:.2f} horas/semana")
print(f"Estados acima da média: {len(acima_media)}")
acima_media
# Out:
# Média nacional (Brasil): 16.99 horas/semana
# Estados acima da média: 12
#               uf_regiao      total
# 16              Alagoas  20.217129
# 12                Ceará  19.499293
# 15           Pernambuco  19.306249
# 14              Paraíba  18.920816
# 17              Sergipe  18.826541
# 13  Rio Grande do Norte  18.307740
# 11                Piauí  17.960366
# 18                Bahia  17.849776
# 20         Minas Gerais  17.502141
# 21       Espírito Santo  17.111106
# 23            São Paulo  17.071295
# 2              Rondônia  17.014162

# %% [markdown]
# Quais estados estão abaixo da média?

# %%
regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]

estados = indicador_1[~indicador_1["uf_regiao"].isin(["Brasil"] + regioes)]

abaixo_media = estados.loc[
    estados["total"] < media_nacional,
    ["uf_regiao", "total"],
].sort_values("total", ascending=False)

print(f"Média nacional (Brasil): {media_nacional:.2f} horas/semana")
print(f"Estados abaixo da média: {len(abaixo_media)}")
abaixo_media
# Out:
# Média nacional (Brasil): 16.99 horas/semana
# Estados abaixo da média: 15
#              uf_regiao      total
# 4             Amazonas  16.807290
# 22      Rio de Janeiro  16.716263
# 10            Maranhão  16.669614
# 6                 Pará  16.474268
# 26      Santa Catarina  16.039355
# 8            Tocantins  15.815781
# 25              Paraná  15.390122
# 27   Rio Grande do Sul  15.356709
# 29  Mato Grosso do Sul  15.309783
# 31               Goiás  15.186471
# 32    Distrito Federal  15.096351
# 30         Mato Grosso  14.239989
# 5              Roraima  13.639257
# 3                 Acre  13.606903
# 7                Amapá  13.586656

# %% [markdown]
# Qual é o percentual de diferença no Brasil que mulheres trabalham mais que homens em casa?

# %%
brasil = indicador_1.loc[indicador_1["uf_regiao"] == "Brasil"].iloc[0]

homem = (brasil["homem_branca"] + brasil["homem_preta_parda"]) / 2
mulher = (brasil["mulher_branca"] + brasil["mulher_preta_parda"]) / 2

# quanto % a mais as mulheres trabalham em relação aos homens
percentual = (mulher - homem) / homem * 100

print(f"Homens (média das cores):   {homem:.2f} h/semana")
print(f"Mulheres (média das cores): {mulher:.2f} h/semana")
print(f"Mulheres trabalham {percentual:.1f}% a mais que homens em casa, no Brasil.")

# recorte por cor (a tabela traz isso de fato)
perc_branca = (brasil["mulher_branca"] / brasil["homem_branca"] - 1) * 100
perc_preta_parda = (brasil["mulher_preta_parda"] / brasil["homem_preta_parda"] - 1) * 100
print(f"Branca:        mulheres +{perc_branca:.1f}%")
print(f"Preta ou parda: mulheres +{perc_preta_parda:.1f}%")
# Out:
# Homens (média das cores):   11.73 h/semana
# Mulheres (média das cores): 21.22 h/semana
# Mulheres trabalham 81.0% a mais que homens em casa, no Brasil.
# Branca:        mulheres +74.3%
# Preta ou parda: mulheres +87.6%

# %% [markdown]
# Agora responda (Com códigos):
# TODAS AS RESPOSTAS DEVEM SER EM PERCENTUAL
# - Quantas horas mulheres pretas trabalham a mais que mulheres brancas em Minas Gerais?
# - Quantas horas mulheres pretas trabalham a mais que homens brancos no Brasil?
# - Quantas horas mulheres pretas trabalham a mais que mulheres brancas no Amapá?
# - Quantas horas mulheres pretas trabalham a mais que mulheres brancas no Rio Grande do Sul?
# - Quantas horas mulheres pretas trabalham a mais que mulheres brancas por região["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"] ?
# - Dentre os estados da região sudeste Quantas horas mulheres pretas trabalham a mais que mulheres brancas?
# -

# %%
mg = indicador_1.loc[indicador_1["uf_regiao"] == "Minas Gerais"].iloc[0]

percentual = (
    (mg["mulher_preta_parda"] - mg["mulher_branca"])
    / mg["mulher_branca"]
) * 100

print(f"Minas Gerais: {percentual:.2f}%")
# Out:
# Minas Gerais: 4.01%

# %%
brasil = indicador_1.loc[indicador_1["uf_regiao"] == "Brasil"].iloc[0]

percentual = (
    (brasil["mulher_preta_parda"] - brasil["homem_branca"])
    / brasil["homem_branca"]
) * 100

print(f"Brasil: {percentual:.2f}%")
# Out:
# Brasil: 88.28%

# %%
amapa = indicador_1.loc[indicador_1["uf_regiao"] == "Amapá"].iloc[0]

percentual = (
    (amapa["mulher_preta_parda"] - amapa["mulher_branca"])
    / amapa["mulher_branca"]
) * 100

print(f"Amapá: {percentual:.2f}%")
# Out:
# Amapá: -4.45%

# %%
rs = indicador_1.loc[indicador_1["uf_regiao"] == "Rio Grande do Sul"].iloc[0]

percentual = (
    (rs["mulher_preta_parda"] - rs["mulher_branca"])
    / rs["mulher_branca"]
) * 100

print(f"Rio Grande do Sul: {percentual:.2f}%")
# Out:
# Rio Grande do Sul: 1.27%

# %%
regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]

resultado = indicador_1[
    indicador_1["uf_regiao"].isin(regioes)
].copy()

resultado["percentual"] = (
    (resultado["mulher_preta_parda"] - resultado["mulher_branca"])
    / resultado["mulher_branca"]
) * 100

for _, linha in resultado.iterrows():
    print(f"{linha['uf_regiao']}: {linha['percentual']:.2f}%")
# Out:
# Norte: 6.42%
# Nordeste: 4.27%
# Sudeste: 6.07%
# Sul: 1.71%
# Centro-Oeste: 6.09%

# %%
sudeste = [
    "Minas Gerais",
    "Espírito Santo",
    "Rio de Janeiro",
    "São Paulo"
]

estados_sudeste = indicador_1[
    indicador_1["uf_regiao"].isin(sudeste)
].copy()

estados_sudeste["percentual"] = (
    (estados_sudeste["mulher_preta_parda"] - estados_sudeste["mulher_branca"])
    / estados_sudeste["mulher_branca"]
) * 100

for _, linha in estados_sudeste.iterrows():
    print(f"{linha['uf_regiao']}: {linha['percentual']:.2f}%")
# Out:
# Minas Gerais: 4.01%
# Espírito Santo: 8.46%
# Rio de Janeiro: 9.13%
# São Paulo: 4.80%

# %% [markdown]
# ## 25. Gráfico — Afazeres domésticos por região e sexo

# %%
# No terminal, uma vez: python -m pip install matplotlib seaborn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Barras agrupadas: homens x mulheres por grande região
reg = indicador_1[indicador_1["uf_regiao"].isin(regioes)].copy()
reg["homens"] = (reg["homem_branca"] + reg["homem_preta_parda"]) / 2
reg["mulheres"] = (reg["mulher_branca"] + reg["mulher_preta_parda"]) / 2

reg_long = reg.melt(
    id_vars="uf_regiao",
    value_vars=["homens", "mulheres"],
    var_name="sexo",
    value_name="horas",
)

fig, ax = plt.subplots(figsize=(9, 5))
sns.barplot(data=reg_long, x="uf_regiao", y="horas", hue="sexo", ax=ax)
ax.set_title("Afazeres domésticos por região e sexo")
ax.set_xlabel("Região")
ax.set_ylabel("Horas / semana")
plt.tight_layout()
plt.savefig("../graficos/afazeres_domesticos_regiao_sexo.png", dpi=150)
plt.show()
